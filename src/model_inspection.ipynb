# %%
from keras.utils.vis_utils import model_to_dot

#import matplotlib.pyplot as plt
#%matplotlib inline

from IPython.display import SVG

#import ipywidgets as ipw

import tcc_all as tdp
from tcc_all import Tcc
# Out:
# Using TensorFlow backend.

# %%
model = tdp.load_keras_model(Tcc.LOAD_MODEL)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~/pie352-tf14/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#
# ~/pie352-tf14/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#
# ~/pie352-tf14/lib/python3.5/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     472             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 473             c_api.TF_GetCode(self.status.status))
#     474     # Delete the underlying status object from memory otherwise it stays alive
#
# InternalError: Dst tensor is not initialized.
# 	 [[Node: _arg_Placeholder_18_0_1/_379 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:GPU:0", send_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device_incarnation=1, tensor_name="edge_161__arg_Placeholder_18_0_1", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:GPU:0"]()]]
#
# During handling of the above exception, another exception occurred:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-2-0677e4d982eb> in <module>()
# ----> 1 model = tdp.load_keras_model(Tcc.LOAD_MODEL)
#
# ~/TCC/src/tcc_all.py in load_keras_model(model_file)
#     525 def load_keras_model(model_file):
#     526     model = load_model(os.path.join(Tcc.OUTPUT_DIR, model_file),
# --> 527                        custom_objects={'tf_auc_roc': tf_auc_roc})
#     528
#     529     return model
#
# ~/pie352-tf14/lib/python3.5/site-packages/keras/models.py in load_model(filepath, custom_objects, compile)
#     287                                        optimizer_weight_names]
#     288             try:
# --> 289                 model.optimizer.set_weights(optimizer_weight_values)
#     290             except ValueError:
#     291                 warnings.warn('Error in loading the saved optimizer '
#
# ~/pie352-tf14/lib/python3.5/site-packages/keras/optimizers.py in set_weights(self, weights)
#     110                                  'provided weight shape ' + str(w.shape))
#     111             weight_value_tuples.append((p, w))
# --> 112         K.batch_set_value(weight_value_tuples)
#     113
#     114     def get_weights(self):
#
# ~/pie352-tf14/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in batch_set_value(tuples)
#    2368             assign_ops.append(assign_op)
#    2369             feed_dict[assign_placeholder] = value
# -> 2370         get_session().run(assign_ops, feed_dict=feed_dict)
#    2371
#    2372
#
# ~/pie352-tf14/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/pie352-tf14/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# ~/pie352-tf14/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/pie352-tf14/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1334         except KeyError:
#    1335           pass
# -> 1336       raise type(e)(node_def, op, message)
#    1337
#    1338   def _extend_graph(self):
#
# InternalError: Dst tensor is not initialized.
# 	 [[Node: _arg_Placeholder_18_0_1/_379 = _Recv[client_terminated=false, recv_device="/job:localhost/replica:0/task:0/device:GPU:0", send_device="/job:localhost/replica:0/task:0/device:CPU:0", send_device_incarnation=1, tensor_name="edge_161__arg_Placeholder_18_0_1", tensor_type=DT_FLOAT, _device="/job:localhost/replica:0/task:0/device:GPU:0"]()]]

# %%
SVG(model_to_dot(model).create(prog='dot', format='svg'))

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# name_input (InputLayer)         (None, 21)           0
# __________________________________________________________________________________________________
# item_desc_input (InputLayer)    (None, 301)          0
# __________________________________________________________________________________________________
# name_embedding (Embedding)      (None, 21, 50)       1000000     name_input[0][0]
# __________________________________________________________________________________________________
# item_desc_embedding (Embedding) (None, 301, 50)      1000000     item_desc_input[0][0]
# __________________________________________________________________________________________________
# category_input (InputLayer)     (None, 1)            0
# __________________________________________________________________________________________________
# brand_input (InputLayer)        (None, 1)            0
# __________________________________________________________________________________________________
# name_embedding_dropout (Spatial (None, 21, 50)       0           name_embedding[0][0]
# __________________________________________________________________________________________________
# item_desc_embedding_dropout (Sp (None, 301, 50)      0           item_desc_embedding[0][0]
# __________________________________________________________________________________________________
# category_embedding (Embedding)  (None, 1, 10)        11150       category_input[0][0]
# __________________________________________________________________________________________________
# brand_embedding (Embedding)     (None, 1, 10)        28730       brand_input[0][0]
# __________________________________________________________________________________________________
# name_lstm_2 (CuDNNLSTM)         (None, 100)          60800       name_embedding_dropout[0][0]
# __________________________________________________________________________________________________
# item_desc_lstm_2 (CuDNNLSTM)    (None, 200)          201600      item_desc_embedding_dropout[0][0]
# __________________________________________________________________________________________________
# category_embedding_dropout (Dro (None, 1, 10)        0           category_embedding[0][0]
# __________________________________________________________________________________________________
# brand_embedding_dropout (Dropou (None, 1, 10)        0           brand_embedding[0][0]
# __________________________________________________________________________________________________
# cond_input (InputLayer)         (None, 1)            0
# __________________________________________________________________________________________________
# ship_input (InputLayer)         (None, 1)            0
# __________________________________________________________________________________________________
# name_lstm_dropout (Dropout)     (None, 100)          0           name_lstm_2[0][0]
# __________________________________________________________________________________________________
# item_desc_lstm_dropout (Dropout (None, 200)          0           item_desc_lstm_2[0][0]
# __________________________________________________________________________________________________
# category_reshape (Reshape)      (None, 10)           0           category_embedding_dropout[0][0]
# __________________________________________________________________________________________________
# brand_reshape (Reshape)         (None, 10)           0           brand_embedding_dropout[0][0]
# __________________________________________________________________________________________________
# input_fusion (Concatenate)      (None, 322)          0           cond_input[0][0]
#                                                                  ship_input[0][0]
#                                                                  name_lstm_dropout[0][0]
#                                                                  item_desc_lstm_dropout[0][0]
#                                                                  category_reshape[0][0]
#                                                                  brand_reshape[0][0]
# __________________________________________________________________________________________________
# fusion_dense_1 (Dense)          (None, 322)          104006      input_fusion[0][0]
# __________________________________________________________________________________________________
# fusion_dense_2 (Dense)          (None, 200)          64600       fusion_dense_1[0][0]
# __________________________________________________________________________________________________
# fusion_dense_3 (Dense)          (None, 1)            201         fusion_dense_2[0][0]
# ==================================================================================================
# Total params: 2,471,087
# Trainable params: 471,087
# Non-trainable params: 2,000,000
# __________________________________________________________________________________________________
